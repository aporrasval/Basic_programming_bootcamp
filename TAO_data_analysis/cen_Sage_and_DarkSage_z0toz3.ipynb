# %%
from astropy.io import fits
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
SAGE_z0_load = fits.open('tao.1950.0.fits')
SAGE_z1_load = fits.open('tao.1958.0.fits')
SAGE_z2_load = fits.open('tao.1960.0.fits')
SAGE_z3_load = fits.open('tao.1956.0.fits')

DSAGE_z0_load = fits.open('tao.1951.0.fits')
DSAGE_z1_load = fits.open('tao.1959.0.fits')
DSAGE_z2_load = fits.open('tao.1961.0.fits')
DSAGE_z3_load = fits.open('tao.1957.0.fits')

# %%
data_z0Sage = SAGE_z0_load[1].data
data_z1Sage = SAGE_z1_load[1].data
data_z2Sage = SAGE_z2_load[1].data
data_z3Sage = SAGE_z3_load[1].data

data_z0DSage = DSAGE_z0_load[1].data
data_z1DSage = DSAGE_z1_load[1].data
data_z2DSage = DSAGE_z2_load[1].data
data_z3DSage = DSAGE_z3_load[1].data

# %%
cols_SAGE = SAGE_z0_load[1].columns
cols_DSAGE = DSAGE_z0_load[1].columns
#print cols_SAGE
#print cols_DSAGE

# %%
############# SAGE ###############
idx_cen_z0Sage = np.where(data_z0Sage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z0Sage  = np.where(data_z0Sage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z0Sage = data_z0Sage[idx_cen_z0Sage]
gal_sat_z0Sage = data_z0Sage[idx_sat_z0Sage]
idx_cen_z1Sage = np.where(data_z1Sage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z1Sage  = np.where(data_z1Sage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z1Sage = data_z1Sage[idx_cen_z1Sage]
gal_sat_z1Sage = data_z1Sage[idx_sat_z1Sage]

idx_cen_z2Sage = np.where(data_z2Sage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z2Sage  = np.where(data_z2Sage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z2Sage = data_z2Sage[idx_cen_z2Sage]
gal_sat_z2Sage = data_z2Sage[idx_sat_z2Sage]

idx_cen_z3Sage = np.where(data_z3Sage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z3Sage  = np.where(data_z3Sage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z3Sage = data_z3Sage[idx_cen_z3Sage]
gal_sat_z3Sage = data_z3Sage[idx_sat_z3Sage]

#### Taking all galaxies with TSM = 0 out of sample
TSM_idx_cen_z0Sage = np.where(gal_cen_z0Sage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z0Sage = gal_cen_z0Sage[TSM_idx_cen_z0Sage]

TSM_idx_cen_z1Sage = np.where(gal_cen_z1Sage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z1Sage = gal_cen_z1Sage[TSM_idx_cen_z1Sage]

TSM_idx_cen_z2Sage = np.where(gal_cen_z2Sage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z2Sage = gal_cen_z2Sage[TSM_idx_cen_z2Sage]

TSM_idx_cen_z3Sage = np.where(gal_cen_z3Sage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z3Sage = gal_cen_z3Sage[TSM_idx_cen_z3Sage]

# %%
############# DARK SAGE ###############
idx_cen_z0DSage = np.where(data_z0DSage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z0DSage  = np.where(data_z0DSage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z0DSage = data_z0DSage[idx_cen_z0DSage]
gal_sat_z0DSage = data_z0DSage[idx_sat_z0DSage]

idx_cen_z1DSage = np.where(data_z1DSage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z1DSage  = np.where(data_z1DSage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z1DSage = data_z1DSage[idx_cen_z1DSage]
gal_sat_z1DSage = data_z1DSage[idx_sat_z1DSage]

idx_cen_z2DSage = np.where(data_z2DSage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z2DSage  = np.where(data_z2DSage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z2DSage = data_z2DSage[idx_cen_z2DSage]
gal_sat_z2DSage = data_z2DSage[idx_sat_z2DSage]

idx_cen_z3DSage = np.where(data_z3DSage[:]['Galaxy_Classification'] == 0) [0]
idx_sat_z3DSage  = np.where(data_z3DSage[:]['Galaxy_Classification'] == 1) [0]
gal_cen_z3DSage = data_z3DSage[idx_cen_z3DSage]
gal_sat_z3DSage = data_z3DSage[idx_sat_z3DSage]

####### DARK SAGE########
#### Taking all galaxies with TSM = 0 out of sample
TSM_idx_cen_z0DSage = np.where(gal_cen_z0DSage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z0DSage = gal_cen_z0DSage[TSM_idx_cen_z0DSage]

TSM_idx_cen_z1DSage = np.where(gal_cen_z1DSage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z1DSage = gal_cen_z1DSage[TSM_idx_cen_z1DSage]

TSM_idx_cen_z2DSage = np.where(gal_cen_z2DSage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z2DSage = gal_cen_z2DSage[TSM_idx_cen_z2DSage]

TSM_idx_cen_z3DSage = np.where(gal_cen_z3DSage[:]['Total_Stellar_Mass']!=0)[0]
gal_cen_z3DSage = gal_cen_z3DSage[TSM_idx_cen_z3DSage]

#### Taking all galaxies with DSM = 0 out of sample
DSM_idx_cen_z0DSage = np.where(gal_cen_z0DSage[:]['Disk_Stellar_Mass']!=0)[0]
gal_cen_z0DSage = gal_cen_z0DSage[DSM_idx_cen_z0DSage]

DSM_idx_cen_z1DSage = np.where(gal_cen_z1DSage[:]['Disk_Stellar_Mass']!=0)[0]
gal_cen_z1DSage = gal_cen_z1DSage[DSM_idx_cen_z1DSage]

DSM_idx_cen_z2DSage = np.where(gal_cen_z2DSage[:]['Disk_Stellar_Mass']!=0)[0]
gal_cen_z2DSage = gal_cen_z2DSage[DSM_idx_cen_z2DSage]

DSM_idx_cen_z3DSage = np.where(gal_cen_z3DSage[:]['Disk_Stellar_Mass']!=0)[0]
gal_cen_z3DSage = gal_cen_z3DSage[DSM_idx_cen_z3DSage]

# %%
############# SAGE ###############

#Setting up variable parameters for central galaxies for redshift z=0
Mvir_cen_z0Sage = 1e10*gal_cen_z0Sage['Mvir']  
Rvir_cen_z0Sage = 1e10*gal_cen_z0Sage['Rvir']
TSM_cen_z0Sage = 1e10*gal_cen_z0Sage['Total_Stellar_Mass']
Bulge_cen_z0Sage = 1e10*gal_cen_z0Sage['Bulge_Stellar_Mass']    #Bulge for morphology
CGMvir_cen_z0Sage = 1e10*gal_cen_z0Sage['Central_Galaxy_Mvir']
xpos_cen_z0Sage = gal_cen_z0Sage['X']
ypos_cen_z0Sage = gal_cen_z0Sage['Y']
zpos_cen_z0Sage = gal_cen_z0Sage['Z']
xvel_cen_z0Sage = gal_cen_z0Sage['X_Velocity']
yvel_cen_z0Sage = gal_cen_z0Sage['Y_Velocity']
zvel_cen_z0Sage = gal_cen_z0Sage['Z_Velocity']
xspin_cen_z0Sage = gal_cen_z0Sage['X_Spin']
yspin_cen_z0Sage = gal_cen_z0Sage['Y_Spin']
zspin_cen_z0Sage = gal_cen_z0Sage['Z_Spin']
pos_cen_z0Sage = np.sqrt(xpos_cen_z0Sage**2 + ypos_cen_z0Sage**2 + zpos_cen_z0Sage**2)
vel_cen_z0Sage = np.sqrt(xvel_cen_z0Sage**2 + yvel_cen_z0Sage**2 + zvel_cen_z0Sage**2)
spin_cen_z0Sage = np.sqrt(xspin_cen_z0Sage**2 + yspin_cen_z0Sage**2 + zspin_cen_z0Sage**2)

#Setting up variable parameters for central galaxies for redshift z=1
Mvir_cen_z1Sage = 1e10*gal_cen_z1Sage['Mvir']   
Rvir_cen_z1Sage = 1e10*gal_cen_z1Sage['Rvir'] 
TSM_cen_z1Sage = 1e10*gal_cen_z1Sage['Total_Stellar_Mass']
Bulge_cen_z1Sage = 1e10*gal_cen_z1Sage['Bulge_Stellar_Mass']    #Bulge for morphology
CGMvir_cen_z1Sage = 1e10*gal_cen_z1Sage['Central_Galaxy_Mvir']
xpos_cen_z1Sage = gal_cen_z1Sage['X']
ypos_cen_z1Sage = gal_cen_z1Sage['Y']
zpos_cen_z1Sage = gal_cen_z1Sage['Z']
xvel_cen_z1Sage = gal_cen_z1Sage['X_Velocity']
yvel_cen_z1Sage = gal_cen_z1Sage['Y_Velocity']
zvel_cen_z1Sage = gal_cen_z1Sage['Z_Velocity']
xspin_cen_z1Sage = gal_cen_z1Sage['X_Spin']
yspin_cen_z1Sage = gal_cen_z1Sage['Y_Spin']
zspin_cen_z1Sage = gal_cen_z1Sage['Z_Spin']
pos_cen_z1Sage = np.sqrt(xpos_cen_z1Sage**2 + ypos_cen_z1Sage**2 + zpos_cen_z1Sage**2)
vel_cen_z1Sage = np.sqrt(xvel_cen_z1Sage**2 + yvel_cen_z1Sage**2 + zvel_cen_z1Sage**2)
spin_cen_z1Sage = np.sqrt(xspin_cen_z1Sage**2 + yspin_cen_z1Sage**2 + zspin_cen_z1Sage**2)

#Setting up variable parameters for central galaxies for redshift z=2
Mvir_cen_z2Sage = 1e10*gal_cen_z2Sage['Mvir'] 
Rvir_cen_z2Sage = 1e10*gal_cen_z2Sage['Rvir']
TSM_cen_z2Sage = 1e10*gal_cen_z2Sage['Total_Stellar_Mass']
Bulge_cen_z2Sage = 1e10*gal_cen_z2Sage['Bulge_Stellar_Mass']    #Bulge for morphology
CGMvir_cen_z2Sage = 1e10*gal_cen_z2Sage['Central_Galaxy_Mvir']
xpos_cen_z2Sage = gal_cen_z2Sage['X']
ypos_cen_z2Sage = gal_cen_z2Sage['Y']
zpos_cen_z2Sage = gal_cen_z2Sage['Z']
xvel_cen_z2Sage = gal_cen_z2Sage['X_Velocity']
yvel_cen_z2Sage = gal_cen_z2Sage['Y_Velocity']
zvel_cen_z2Sage = gal_cen_z2Sage['Z_Velocity']
xspin_cen_z2Sage = gal_cen_z2Sage['X_Spin']
yspin_cen_z2Sage = gal_cen_z2Sage['Y_Spin']
zspin_cen_z2Sage = gal_cen_z2Sage['Z_Spin']
pos_cen_z2Sage = np.sqrt(xpos_cen_z2Sage**2 + ypos_cen_z2Sage**2 + zpos_cen_z2Sage**2)
vel_cen_z2Sage = np.sqrt(xvel_cen_z2Sage**2 + yvel_cen_z2Sage**2 + zvel_cen_z2Sage**2)
spin_cen_z2Sage = np.sqrt(xspin_cen_z2Sage**2 + yspin_cen_z2Sage**2 + zspin_cen_z2Sage**2)

#Setting up variable parameters for central galaxies for redshift z=3
Mvir_cen_z3Sage = 1e10*gal_cen_z3Sage['Mvir']   
Rvir_cen_z3Sage = 1e10*gal_cen_z3Sage['Rvir'] 
TSM_cen_z3Sage = 1e10*gal_cen_z3Sage['Total_Stellar_Mass']
Bulge_cen_z3Sage = 1e10*gal_cen_z3Sage['Bulge_Stellar_Mass']    #Bulge for morphology
CGMvir_cen_z3Sage = 1e10*gal_cen_z3Sage['Central_Galaxy_Mvir']
xpos_cen_z3Sage = gal_cen_z3Sage['X']
ypos_cen_z3Sage = gal_cen_z3Sage['Y']
zpos_cen_z3Sage = gal_cen_z3Sage['Z']
xvel_cen_z3Sage = gal_cen_z3Sage['X_Velocity']
yvel_cen_z3Sage = gal_cen_z3Sage['Y_Velocity']
zvel_cen_z3Sage = gal_cen_z3Sage['Z_Velocity']
xspin_cen_z3Sage = gal_cen_z3Sage['X_Spin']
yspin_cen_z3Sage = gal_cen_z3Sage['Y_Spin']
zspin_cen_z3Sage = gal_cen_z3Sage['Z_Spin']
pos_cen_z3Sage = np.sqrt(xpos_cen_z3Sage**2 + ypos_cen_z3Sage**2 + zpos_cen_z3Sage**2)
vel_cen_z3Sage = np.sqrt(xvel_cen_z3Sage**2 + yvel_cen_z3Sage**2 + zvel_cen_z3Sage**2)
spin_cen_z3Sage = np.sqrt(xspin_cen_z3Sage**2 + yspin_cen_z3Sage**2 + zspin_cen_z3Sage**2)

# %%
#######DARK SAGE########
#Setting up variable parameters for central galaxies for redshift z=0
Mvir_cen_z0DSage = 1e10*gal_cen_z0DSage['Mvir']     
Rvir_cen_z0DSage = 1e10*gal_cen_z0DSage['Rvir'] 
TSM_cen_z0DSage = 1e10*gal_cen_z0DSage['Total_Stellar_Mass']
Bulgeinstadriven_cen_z0DSage = 1e10*gal_cen_z0DSage['Instability-driven_Bulge_Mass']    #Bulge for morphology
Bulgemergerdriven_cen_z0DSage = 1e10*gal_cen_z0DSage['Merger-driven_Bulge_Mass']    #Bulge for morphology
Bulgepseudo_cen_z0DSage = 1e10*gal_cen_z0DSage['Pseudobulge_Mass']    #Bulge for morphology
DSM_cen_z0DSage = 1e10*gal_cen_z0DSage['Disk_Stellar_Mass']
JSD_cen_z0DSage = 1e10*gal_cen_z0DSage['j_Stellar_Disk']
CGMvir_cen_z0DSage = 1e10*gal_cen_z0DSage['Central_Galaxy_Mvir']
xpos_cen_z0DSage = gal_cen_z0DSage['X']
ypos_cen_z0DSage = gal_cen_z0DSage['Y']
zpos_cen_z0DSage = gal_cen_z0DSage['Z']
xvel_cen_z0DSage = gal_cen_z0DSage['X_Velocity']
yvel_cen_z0DSage = gal_cen_z0DSage['Y_Velocity']
zvel_cen_z0DSage = gal_cen_z0DSage['Z_Velocity']
#Stellar Disk spin central
xSDspin_cen_z0DSage = gal_cen_z0DSage['X_Spin_of_Stellar_Disk']
ySDspin_cen_z0DSage = gal_cen_z0DSage['Y_Spin_of_Stellar_Disk']
zSDspin_cen_z0DSage = gal_cen_z0DSage['Z_Spin_of_Stellar_Disk']
#Gas Disk spin central
xGDspin_cen_z0DSage = gal_cen_z0DSage['X_Spin_of_Gas_Disk']
yGDspin_cen_z0DSage = gal_cen_z0DSage['Y_Spin_of_Gas_Disk']
zGDspin_cen_z0DSage = gal_cen_z0DSage['Z_Spin_of_Gas_Disk']
#Halo J central
xhaloJ_cen_z0DSage = gal_cen_z0DSage['jX_Halo']
yhaloJ_cen_z0DSage = gal_cen_z0DSage['jY_Halo']
zhaloJ_cen_z0DSage = gal_cen_z0DSage['jZ_Halo']

pos_cen_z0DSage = np.sqrt(xpos_cen_z0DSage**2 + ypos_cen_z0DSage**2 + zpos_cen_z0DSage**2)
vel_cen_z0DSage = np.sqrt(xvel_cen_z0DSage**2 + yvel_cen_z0DSage**2 + zvel_cen_z0DSage**2)
SDspin_cen_z0DSage = np.sqrt(xSDspin_cen_z0DSage**2 + ySDspin_cen_z0DSage**2 + zSDspin_cen_z0DSage**2)
GDspin_cen_z0DSage = np.sqrt(xGDspin_cen_z0DSage**2 + yGDspin_cen_z0DSage**2 + zGDspin_cen_z0DSage**2)
haloJ_cen_z0DSage = np.sqrt(xhaloJ_cen_z0DSage**2 + yhaloJ_cen_z0DSage**2 + zhaloJ_cen_z0DSage**2)



#Setting up variable parameters for central galaxies for redshift z=1
Mvir_cen_z1DSage = 1e10*gal_cen_z1DSage['Mvir'] 
Rvir_cen_z1DSage = 1e10*gal_cen_z1DSage['Rvir'] 
TSM_cen_z1DSage = 1e10*gal_cen_z1DSage['Total_Stellar_Mass']
Bulgeinstadriven_cen_z1DSage = 1e10*gal_cen_z1DSage['Instability-driven_Bulge_Mass']    #Bulge for morphology
Bulgemergerdriven_cen_z1DSage = 1e10*gal_cen_z1DSage['Merger-driven_Bulge_Mass']    #Bulge for morphology
Bulgepseudo_cen_z1DSage = 1e10*gal_cen_z1DSage['Pseudobulge_Mass']    #Bulge for morphology
DSM_cen_z1DSage = 1e10*gal_cen_z1DSage['Disk_Stellar_Mass']
JSD_cen_z1DSage = 1e10*gal_cen_z1DSage['j_Stellar_Disk']
CGMvir_cen_z1DSage = 1e10*gal_cen_z1DSage['Central_Galaxy_Mvir']
xpos_cen_z1DSage = gal_cen_z1DSage['X']
ypos_cen_z1DSage = gal_cen_z1DSage['Y']
zpos_cen_z1DSage = gal_cen_z1DSage['Z']
xvel_cen_z1DSage = gal_cen_z1DSage['X_Velocity']
yvel_cen_z1DSage = gal_cen_z1DSage['Y_Velocity']
zvel_cen_z1DSage = gal_cen_z1DSage['Z_Velocity']
#Stellar Disk spin central
xSDspin_cen_z1DSage = gal_cen_z1DSage['X_Spin_of_Stellar_Disk']
ySDspin_cen_z1DSage = gal_cen_z1DSage['Y_Spin_of_Stellar_Disk']
zSDspin_cen_z1DSage = gal_cen_z1DSage['Z_Spin_of_Stellar_Disk']
#Gas Disk spin central
xGDspin_cen_z1DSage = gal_cen_z1DSage['X_Spin_of_Gas_Disk']
yGDspin_cen_z1DSage = gal_cen_z1DSage['Y_Spin_of_Gas_Disk']
zGDspin_cen_z1DSage = gal_cen_z1DSage['Z_Spin_of_Gas_Disk']
#Halo J central
xhaloJ_cen_z1DSage = gal_cen_z1DSage['jX_Halo']
yhaloJ_cen_z1DSage = gal_cen_z1DSage['jY_Halo']
zhaloJ_cen_z1DSage = gal_cen_z1DSage['jZ_Halo']

pos_cen_z1DSage = np.sqrt(xpos_cen_z1DSage**2 + ypos_cen_z1DSage**2 + zpos_cen_z1DSage**2)
vel_cen_z1DSage = np.sqrt(xvel_cen_z1DSage**2 + yvel_cen_z1DSage**2 + zvel_cen_z1DSage**2)
SDspin_cen_z1DSage = np.sqrt(xSDspin_cen_z1DSage**2 + ySDspin_cen_z1DSage**2 + zSDspin_cen_z1DSage**2)
GDspin_cen_z1DSage = np.sqrt(xGDspin_cen_z1DSage**2 + yGDspin_cen_z1DSage**2 + zGDspin_cen_z1DSage**2)
haloJ_cen_z1DSage = np.sqrt(xhaloJ_cen_z1DSage**2 + yhaloJ_cen_z1DSage**2 + zhaloJ_cen_z1DSage**2)

#Setting up variable parameters for central galaxies for redshift z=2
Mvir_cen_z2DSage = 1e10*gal_cen_z2DSage['Mvir']  
Rvir_cen_z2DSage = 1e10*gal_cen_z2DSage['Rvir'] 
TSM_cen_z2DSage = 1e10*gal_cen_z2DSage['Total_Stellar_Mass']
Bulgeinstadriven_cen_z2DSage = 1e10*gal_cen_z2DSage['Instability-driven_Bulge_Mass']    #Bulge for morphology
Bulgemergerdriven_cen_z2DSage = 1e10*gal_cen_z2DSage['Merger-driven_Bulge_Mass']    #Bulge for morphology
Bulgepseudo_cen_z2DSage = 1e10*gal_cen_z2DSage['Pseudobulge_Mass']    #Bulge for morphology
DSM_cen_z2DSage = 1e10*gal_cen_z2DSage['Disk_Stellar_Mass']
JSD_cen_z2DSage = 1e10*gal_cen_z2DSage['j_Stellar_Disk']
CGMvir_cen_z2DSage = 1e10*gal_cen_z2DSage['Central_Galaxy_Mvir']
xpos_cen_z2DSage = gal_cen_z2DSage['X']
ypos_cen_z2DSage = gal_cen_z2DSage['Y']
zpos_cen_z2DSage = gal_cen_z2DSage['Z']
xvel_cen_z2DSage = gal_cen_z2DSage['X_Velocity']
yvel_cen_z2DSage = gal_cen_z2DSage['Y_Velocity']
zvel_cen_z2DSage = gal_cen_z2DSage['Z_Velocity']
#Stellar Disk spin central
xSDspin_cen_z2DSage = gal_cen_z2DSage['X_Spin_of_Stellar_Disk']
ySDspin_cen_z2DSage = gal_cen_z2DSage['Y_Spin_of_Stellar_Disk']
zSDspin_cen_z2DSage = gal_cen_z2DSage['Z_Spin_of_Stellar_Disk']
#Gas Disk spin central
xGDspin_cen_z2DSage = gal_cen_z2DSage['X_Spin_of_Gas_Disk']
yGDspin_cen_z2DSage = gal_cen_z2DSage['Y_Spin_of_Gas_Disk']
zGDspin_cen_z2DSage = gal_cen_z2DSage['Z_Spin_of_Gas_Disk']
#Halo J central
xhaloJ_cen_z2DSage = gal_cen_z2DSage['jX_Halo']
yhaloJ_cen_z2DSage = gal_cen_z2DSage['jY_Halo']
zhaloJ_cen_z2DSage = gal_cen_z2DSage['jZ_Halo']

pos_cen_z2DSage = np.sqrt(xpos_cen_z2DSage**2 + ypos_cen_z2DSage**2 + zpos_cen_z2DSage**2)
vel_cen_z2DSage = np.sqrt(xvel_cen_z2DSage**2 + yvel_cen_z2DSage**2 + zvel_cen_z2DSage**2)
SDspin_cen_z2DSage = np.sqrt(xSDspin_cen_z2DSage**2 + ySDspin_cen_z2DSage**2 + zSDspin_cen_z2DSage**2)
GDspin_cen_z2DSage = np.sqrt(xGDspin_cen_z2DSage**2 + yGDspin_cen_z2DSage**2 + zGDspin_cen_z2DSage**2)
haloJ_cen_z2DSage = np.sqrt(xhaloJ_cen_z2DSage**2 + yhaloJ_cen_z2DSage**2 + zhaloJ_cen_z2DSage**2)

#Setting up variable parameters for central galaxies for redshift z=3
Mvir_cen_z3DSage = 1e10*gal_cen_z3DSage['Mvir'] 
Rvir_cen_z3DSage = 1e10*gal_cen_z3DSage['Rvir']
TSM_cen_z3DSage = 1e10*gal_cen_z3DSage['Total_Stellar_Mass']
Bulgeinstadriven_cen_z3DSage = 1e10*gal_cen_z3DSage['Instability-driven_Bulge_Mass']    #Bulge for morphology
Bulgemergerdriven_cen_z3DSage = 1e10*gal_cen_z3DSage['Merger-driven_Bulge_Mass']    #Bulge for morphology
Bulgepseudo_cen_z3DSage = 1e10*gal_cen_z3DSage['Pseudobulge_Mass']    #Bulge for morphology
DSM_cen_z3DSage = 1e10*gal_cen_z3DSage['Disk_Stellar_Mass']
JSD_cen_z3DSage = 1e10*gal_cen_z3DSage['j_Stellar_Disk']
CGMvir_cen_z3DSage = 1e10*gal_cen_z3DSage['Central_Galaxy_Mvir']
xpos_cen_z3DSage = gal_cen_z3DSage['X']
ypos_cen_z3DSage = gal_cen_z3DSage['Y']
zpos_cen_z3DSage = gal_cen_z3DSage['Z']
xvel_cen_z3DSage = gal_cen_z3DSage['X_Velocity']
yvel_cen_z3DSage = gal_cen_z3DSage['Y_Velocity']
zvel_cen_z3DSage = gal_cen_z3DSage['Z_Velocity']
#Stellar Disk spin central
xSDspin_cen_z3DSage = gal_cen_z3DSage['X_Spin_of_Stellar_Disk']
ySDspin_cen_z3DSage = gal_cen_z3DSage['Y_Spin_of_Stellar_Disk']
zSDspin_cen_z3DSage = gal_cen_z3DSage['Z_Spin_of_Stellar_Disk']
#Gas Disk spin central
xGDspin_cen_z3DSage = gal_cen_z3DSage['X_Spin_of_Gas_Disk']
yGDspin_cen_z3DSage = gal_cen_z3DSage['Y_Spin_of_Gas_Disk']
zGDspin_cen_z3DSage = gal_cen_z3DSage['Z_Spin_of_Gas_Disk']
#Halo J central
xhaloJ_cen_z3DSage = gal_cen_z3DSage['jX_Halo']
yhaloJ_cen_z3DSage = gal_cen_z3DSage['jY_Halo']
zhaloJ_cen_z3DSage = gal_cen_z3DSage['jZ_Halo']

pos_cen_z3DSage = np.sqrt(xpos_cen_z3DSage**2 + ypos_cen_z3DSage**2 + zpos_cen_z3DSage**2)
vel_cen_z3DSage = np.sqrt(xvel_cen_z3DSage**2 + yvel_cen_z3DSage**2 + zvel_cen_z3DSage**2)
SDspin_cen_z3DSage = np.sqrt(xSDspin_cen_z3DSage**2 + ySDspin_cen_z3DSage**2 + zSDspin_cen_z3DSage**2)
GDspin_cen_z3DSage = np.sqrt(xGDspin_cen_z3DSage**2 + yGDspin_cen_z3DSage**2 + zGDspin_cen_z3DSage**2)
haloJ_cen_z3DSage = np.sqrt(xhaloJ_cen_z3DSage**2 + yhaloJ_cen_z3DSage**2 + zhaloJ_cen_z3DSage**2)

# %%
############# SAGE ###############
failval = np.nan
# failval = -999
mean_func = np.nanmean
std_func = np.nanstd
Mvir_bins = np.logspace(10, 15, 15)


#centrals at Redshift 0
idx_Mvir_cen_z0Sage = np.digitize(Mvir_cen_z0Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z0Sage = np.array([ mean_func(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z0Sage = np.array([ mean_func(TSM_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z0Sage = np.array([ std_func(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z0Sage = np.array([ std_func(TSM_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 1
idx_Mvir_cen_z1Sage = np.digitize(Mvir_cen_z1Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z1Sage = np.array([ mean_func(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z1Sage = np.array([ mean_func(TSM_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z1Sage = np.array([ std_func(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z1Sage = np.array([ std_func(TSM_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 2
idx_Mvir_cen_z2Sage = np.digitize(Mvir_cen_z2Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z2Sage = np.array([ mean_func(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z2Sage = np.array([ mean_func(TSM_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z2Sage = np.array([ std_func(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z2Sage = np.array([ std_func(TSM_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 3
idx_Mvir_cen_z3Sage = np.digitize(Mvir_cen_z3Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z3Sage = np.array([ mean_func(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z3Sage = np.array([ mean_func(TSM_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z3Sage = np.array([ std_func(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z3Sage = np.array([ std_func(TSM_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

# %%
####### DARK SAGE ########
#centrals at Redshift 0
idx_Mvir_cen_z0DSage = np.digitize(Mvir_cen_z0DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z0DSage = np.array([ mean_func(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z0DSage = np.array([ mean_func(TSM_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z0DSage = np.array([ std_func(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z0DSage = np.array([ std_func(TSM_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#centrals at Redshift 1
idx_Mvir_cen_z1DSage = np.digitize(Mvir_cen_z1DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z1DSage = np.array([ mean_func(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z1DSage = np.array([ mean_func(TSM_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z1DSage = np.array([ std_func(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z1DSage = np.array([ std_func(TSM_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#centrals at Redshift 2
idx_Mvir_cen_z2DSage = np.digitize(Mvir_cen_z2DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z2DSage = np.array([ mean_func(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z2DSage = np.array([ mean_func(TSM_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z2DSage = np.array([ std_func(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z2DSage = np.array([ std_func(TSM_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#centrals at Redshift 3
idx_Mvir_cen_z3DSage = np.digitize(Mvir_cen_z3DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z3DSage = np.array([ mean_func(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_mean_z3DSage = np.array([ mean_func(TSM_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z3DSage = np.array([ std_func(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
TSM_cen_std_z3DSage = np.array([ std_func(TSM_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

# %%
plt.figure(figsize=(10, 8))

plt.subplot(221)
plt.errorbar(Mvir_cen_mean_z0Sage,
             TSM_cen_mean_z0Sage,
            yerr=TSM_cen_std_z0Sage,
            marker='o', color='b', label='SAGE z=0')

plt.errorbar(Mvir_cen_mean_z1Sage,
             TSM_cen_mean_z1Sage,
            yerr=TSM_cen_std_z1Sage,
            marker='o', color='g', label='SAGE z=1')

plt.errorbar(Mvir_cen_mean_z2Sage,
             TSM_cen_mean_z2Sage,
            yerr=TSM_cen_std_z2Sage,
            marker='o', color='r', label='SAGE z=2')

plt.errorbar(Mvir_cen_mean_z3Sage,
             TSM_cen_mean_z3Sage,
            yerr=TSM_cen_std_z3Sage,
            marker='o', color='k', label='SAGE z=3')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Mvir $M_{\odot}$ /h')
plt.ylabel('Total Stellar Mass $M_{\odot}$ /h')
plt.title('Central Galaxies Mvir vs. Stellar Mass ')
plt.legend(loc=2, numpoints=1)
plt.axis([1e11, 1e15, 1e9, 1e12])

plt.subplot(222)
plt.errorbar(Mvir_cen_mean_z0DSage,
             TSM_cen_mean_z0DSage,
            yerr=TSM_cen_std_z0DSage,
            marker='o', color='b', label='DSAGE z=0')

plt.errorbar(Mvir_cen_mean_z1DSage,
             TSM_cen_mean_z1DSage,
            yerr=TSM_cen_std_z1DSage,
            marker='o', color='g', label='DSAGE z=1')

plt.errorbar(Mvir_cen_mean_z2DSage,
             TSM_cen_mean_z2DSage,
            yerr=TSM_cen_std_z2DSage,
            marker='o', color='r', label='DSAGE z=2')

plt.errorbar(Mvir_cen_mean_z3DSage,
             TSM_cen_mean_z3DSage,
            yerr=TSM_cen_std_z3DSage,
            marker='o', color='k', label='DSAGE z=3')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Mvir $M_{\odot}$ /h')
plt.ylabel('Total Stellar Mass $M_{\odot}$ /h')
plt.title('Central Galaxies Mvir vs. Stellar Mass ')
plt.legend(loc=2, numpoints=1)
plt.axis([1e11, 1e15, 1e9, 1e12])

plt.subplots_adjust(top=0.92, bottom=0.001, left=0.10, right=0.95, hspace=0.6,
                    wspace=0.35)

plt.style.use('seaborn-notebook')
plt.savefig('Centrals_Mvir_TSM_SAGE_DARKSAGE_z0toz3.png')
plt.show()

# %%
############# SAGE ###############
#centrals at Redshift 0
idx_Mvir_cen_z0Sage = np.digitize(Mvir_cen_z0Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z0Sage = np.array([ mean_func(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z0Sage = np.array([ mean_func(spin_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z0Sage = np.array([ std_func(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z0Sage = np.array([ std_func(spin_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) if len(Mvir_cen_z0Sage[idx_Mvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#centrals at Redshift 1
idx_Mvir_cen_z1Sage = np.digitize(Mvir_cen_z1Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z1Sage = np.array([ mean_func(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z1Sage = np.array([ mean_func(spin_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z1Sage = np.array([ std_func(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z1Sage = np.array([ std_func(spin_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) if len(Mvir_cen_z1Sage[idx_Mvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 2
idx_Mvir_cen_z2Sage = np.digitize(Mvir_cen_z2Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z2Sage = np.array([ mean_func(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z2Sage = np.array([ mean_func(spin_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z2Sage = np.array([ std_func(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z2Sage = np.array([ std_func(spin_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) if len(Mvir_cen_z2Sage[idx_Mvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 3
idx_Mvir_cen_z3Sage = np.digitize(Mvir_cen_z3Sage, Mvir_bins)
#Mean
Mvir_cen_mean_z3Sage = np.array([ mean_func(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z3Sage = np.array([ mean_func(spin_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z3Sage = np.array([ std_func(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z3Sage = np.array([ std_func(spin_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) if len(Mvir_cen_z3Sage[idx_Mvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

# %%
######## DARK SAGE ###########
#centrals at Redshift 0
idx_Mvir_cen_z0DSage = np.digitize(Mvir_cen_z0DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z0DSage = np.array([ mean_func(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z0DSage = np.array([ mean_func(haloJ_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z0DSage = np.array([ std_func(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z0DSage = np.array([ std_func(haloJ_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) if len(Mvir_cen_z0DSage[idx_Mvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 1
idx_Mvir_cen_z1DSage = np.digitize(Mvir_cen_z1DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z1DSage = np.array([ mean_func(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z1DSage = np.array([ mean_func(haloJ_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z1DSage = np.array([ std_func(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z1DSage = np.array([ std_func(haloJ_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) if len(Mvir_cen_z1DSage[idx_Mvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 2
idx_Mvir_cen_z2DSage = np.digitize(Mvir_cen_z2DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z2DSage = np.array([ mean_func(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z2DSage = np.array([ mean_func(haloJ_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z2DSage = np.array([ std_func(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z2DSage = np.array([ std_func(haloJ_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) if len(Mvir_cen_z2DSage[idx_Mvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 3
idx_Mvir_cen_z3DSage = np.digitize(Mvir_cen_z3DSage, Mvir_bins)
#Mean
Mvir_cen_mean_z3DSage = np.array([ mean_func(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z3DSage = np.array([ mean_func(haloJ_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#Standard Deviation
Mvir_cen_std_z3DSage = np.array([ std_func(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z3DSage = np.array([ std_func(haloJ_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) if len(Mvir_cen_z3DSage[idx_Mvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(121, axisbg='white')
ax2 = fig.add_subplot(122, axisbg='white', sharey=ax1)
# ax1
ax1.errorbar(Mvir_cen_mean_z0Sage,
             spin_cen_mean_z0Sage,
            yerr=spin_cen_std_z0Sage,
            xerr=Mvir_cen_std_z0Sage,
            marker='o', color='b', label='SAGE z=0')

ax1.errorbar(Mvir_cen_mean_z1Sage,
             spin_cen_mean_z1Sage,
            yerr=spin_cen_std_z1Sage,
            xerr=Mvir_cen_std_z1Sage,
            marker='o', color='g', label='SAGE z=1')

ax1.errorbar(Mvir_cen_mean_z2Sage,
             spin_cen_mean_z2Sage,
            yerr=spin_cen_std_z2Sage,
            xerr=Mvir_cen_std_z2Sage,
            marker='o', color='r', label='SAGE z=2')

ax1.errorbar(Mvir_cen_mean_z3Sage,
             spin_cen_mean_z3Sage,
            yerr=spin_cen_std_z3Sage,
            xerr=Mvir_cen_std_z3Sage,
            marker='o', color='k', label='SAGE z=3')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Mvir $M_{\odot}$ /h')
ax1.set_ylabel('Halo Spin (km/s)')
ax1.set_title('Central Galaxies Mvir vs. Halo Spin ')
ax1.legend(loc=2, numpoints=1)
# ax2
ax2.errorbar(Mvir_cen_mean_z0DSage,
             haloJ_cen_mean_z0DSage,
             yerr=haloJ_cen_std_z0DSage,
             xerr=Mvir_cen_std_z0DSage,
             marker='o', color='b', label='DSAGE z=0')

ax2.errorbar(Mvir_cen_mean_z1DSage,
              haloJ_cen_mean_z1DSage,
             yerr=haloJ_cen_std_z1DSage,
             xerr=Mvir_cen_std_z1DSage,
             marker='o', color='g', label='DSAGE z=1')

ax2.errorbar(Mvir_cen_mean_z2DSage,
              haloJ_cen_mean_z2DSage,
             yerr=haloJ_cen_std_z2DSage,
             xerr=Mvir_cen_std_z2DSage,
             marker='o', color='r', label='DSAGE z=2')

ax2.errorbar(Mvir_cen_mean_z3DSage,
              haloJ_cen_mean_z3DSage,
             yerr=haloJ_cen_std_z3DSage,
             xerr=Mvir_cen_std_z3DSage,
             marker='o', color='k', label='DSAGE z=3')

ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('Mvir $M_{\odot}$ /h')
ax2.set_ylabel('Halo Spin (km/s)')
ax2.set_title('Central Galaxies Mvir vs. Halo Spin ')
ax2.legend(loc=2, numpoints=1)
# Labels
plt.show()
# Out:
# /fs1/porrasaj/anaconda2/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
############# SAGE ###############
#centrals at Redshift 0
idx_Rvir_cen_z0Sage = np.digitize(Rvir_cen_z0Sage, Mvir_bins)
#Mean
Rvir_cen_mean_z0Sage = np.array([ mean_func(Rvir_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) if len(Rvir_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z0Sage = np.array([ mean_func(spin_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) if len(Rvir_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Rvir_cen_std_z0Sage = np.array([ std_func(Rvir_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) if len(Rvir_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z0Sage = np.array([ std_func(spin_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) if len(Rvir_cen_z0Sage[idx_Rvir_cen_z0Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#centrals at Redshift 1
idx_Rvir_cen_z1Sage = np.digitize(Rvir_cen_z1Sage, Mvir_bins)
#Mean
Rvir_cen_mean_z1Sage = np.array([ mean_func(Rvir_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) if len(Rvir_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z1Sage = np.array([ mean_func(spin_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) if len(Rvir_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Rvir_cen_std_z1Sage = np.array([ std_func(Rvir_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) if len(Rvir_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z1Sage = np.array([ std_func(spin_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) if len(Rvir_cen_z1Sage[idx_Rvir_cen_z1Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 2
idx_Rvir_cen_z2Sage = np.digitize(Rvir_cen_z2Sage, Mvir_bins)
#Mean
Rvir_cen_mean_z2Sage = np.array([ mean_func(Rvir_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) if len(Rvir_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z2Sage = np.array([ mean_func(spin_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) if len(Rvir_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Rvir_cen_std_z2Sage = np.array([ std_func(Rvir_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) if len(Rvir_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z2Sage = np.array([ std_func(spin_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) if len(Rvir_cen_z2Sage[idx_Rvir_cen_z2Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 3
idx_Rvir_cen_z3Sage = np.digitize(Rvir_cen_z3Sage, Mvir_bins)
#Mean
Rvir_cen_mean_z3Sage = np.array([ mean_func(Rvir_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) if len(Rvir_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_mean_z3Sage = np.array([ mean_func(spin_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) if len(Rvir_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Rvir_cen_std_z3Sage = np.array([ std_func(Rvir_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) if len(Rvir_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
spin_cen_std_z3Sage = np.array([ std_func(spin_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) if len(Rvir_cen_z3Sage[idx_Rvir_cen_z3Sage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

# %%
######## DARK SAGE ###########
#centrals at Redshift 0
idx_Rvir_cen_z0DSage = np.digitize(Rvir_cen_z0DSage, Mvir_bins)
#Mean
Rvir_cen_mean_z0DSage = np.array([ mean_func(Rvir_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) if len(Rvir_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z0DSage = np.array([ mean_func(haloJ_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) if len(Rvir_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Rvir_cen_std_z0DSage = np.array([ std_func(Rvir_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) if len(Rvir_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z0DSage = np.array([ std_func(haloJ_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) if len(Rvir_cen_z0DSage[idx_Rvir_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 1
idx_Rvir_cen_z1DSage = np.digitize(Rvir_cen_z1DSage, Mvir_bins)
#Mean
Rvir_cen_mean_z1DSage = np.array([ mean_func(Rvir_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) if len(Rvir_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z1DSage = np.array([ mean_func(haloJ_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) if len(Rvir_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Rvir_cen_std_z1DSage = np.array([ std_func(Rvir_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) if len(Rvir_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z1DSage = np.array([ std_func(haloJ_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) if len(Rvir_cen_z1DSage[idx_Rvir_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 2
idx_Rvir_cen_z2DSage = np.digitize(Rvir_cen_z2DSage, Mvir_bins)
#Mean
Rvir_cen_mean_z2DSage = np.array([ mean_func(Rvir_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) if len(Rvir_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z2DSage = np.array([ mean_func(haloJ_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) if len(Rvir_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
Mvir_cen_std_z2DSage = np.array([ std_func(Rvir_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) if len(Rvir_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z2DSage = np.array([ std_func(haloJ_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) if len(Rvir_cen_z2DSage[idx_Rvir_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 3
idx_Rvir_cen_z3DSage = np.digitize(Mvir_cen_z3DSage, Mvir_bins)
#Mean
Rvir_cen_mean_z3DSage = np.array([ mean_func(Rvir_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) if len(Rvir_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z3DSage = np.array([ mean_func(haloJ_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) if len(Rvir_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#Standard Deviation
Rvir_cen_std_z3DSage = np.array([ std_func(Rvir_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) if len(Rvir_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z3DSage = np.array([ std_func(haloJ_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) if len(Rvir_cen_z3DSage[idx_Rvir_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

# %%
###TESTING UP

# %%
######## DARK SAGE ###########
#centrals at Redshift 0
idx_DSM_cen_z0DSage = np.digitize(DSM_cen_z0DSage, Mvir_bins)
#Mean
DSM_cen_mean_z0DSage = np.array([ mean_func(DSM_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) if len(DSM_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z0DSage = np.array([ mean_func(haloJ_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) if len(DSM_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
DSM_cen_std_z0DSage = np.array([ std_func(DSM_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) if len(DSM_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z0DSage = np.array([ std_func(haloJ_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) if len(DSM_cen_z0DSage[idx_DSM_cen_z0DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 1
idx_DSM_cen_z1DSage = np.digitize(DSM_cen_z1DSage, Mvir_bins)
#Mean
DSM_cen_mean_z1DSage = np.array([ mean_func(DSM_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) if len(DSM_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z1DSage = np.array([ mean_func(haloJ_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) if len(DSM_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
DSM_cen_std_z1DSage = np.array([ std_func(DSM_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) if len(DSM_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z1DSage = np.array([ std_func(haloJ_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) if len(DSM_cen_z1DSage[idx_DSM_cen_z1DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 2
idx_DSM_cen_z2DSage = np.digitize(DSM_cen_z2DSage, Mvir_bins)
#Mean
DSM_cen_mean_z2DSage = np.array([ mean_func(DSM_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) if len(DSM_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z2DSage = np.array([ mean_func(haloJ_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) if len(DSM_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
#Standard Deviation
DSM_cen_std_z2DSage = np.array([ std_func(DSM_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) if len(DSM_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z2DSage = np.array([ std_func(haloJ_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) if len(DSM_cen_z2DSage[idx_DSM_cen_z2DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])


#centrals at Redshift 3
idx_DSM_cen_z3DSage = np.digitize(DSM_cen_z3DSage, Mvir_bins)
#Mean
DSM_cen_mean_z3DSage = np.array([ mean_func(DSM_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) if len(DSM_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_mean_z3DSage = np.array([ mean_func(haloJ_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) if len(DSM_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

#Standard Deviation
DSM_cen_std_z3DSage = np.array([ std_func(DSM_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) if len(DSM_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])
haloJ_cen_std_z3DSage = np.array([ std_func(haloJ_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) if len(DSM_cen_z3DSage[idx_DSM_cen_z3DSage==ii]) > 0 else failval for ii in range(1, len(Mvir_bins))])

# %%
plt.errorbar(DSM_cen_mean_z0DSage,
             haloJ_cen_mean_z0DSage,
            yerr=haloJ_cen_std_z0DSage,
            marker='o', color='b', label='DSAGE z=0')

plt.errorbar(DSM_cen_mean_z1DSage,
             haloJ_cen_mean_z1DSage,
            yerr=haloJ_cen_std_z1DSage,
            marker='o', color='g', label='DSAGE z=1')

plt.errorbar(DSM_cen_mean_z2DSage,
             haloJ_cen_mean_z2DSage,
            yerr=haloJ_cen_std_z2DSage,
            marker='o', color='r', label='DSAGE z=2')

plt.errorbar(DSM_cen_mean_z3DSage,
             haloJ_cen_mean_z3DSage,
            yerr=haloJ_cen_std_z3DSage,
            marker='o', color='k', label='DSAGE z=3')

plt.xscale('log')
plt.yscale('log')
plt.xlabel('Disk Stellar Mass $M_{\odot}$ /h')
plt.ylabel('Halo Spin (km/s)')
plt.title('Central Disk Stellar Mass vs. Halo Spin')
plt.legend(loc=2, numpoints=1)


plt.subplots_adjust(top=0.92, bottom=0.001, left=0.10, right=0.95, hspace=0.6,
                    wspace=0.35)
plt.savefig('Centrals_DSM_halospin_DARKSAGE_z0toz3.png')
plt.show()

# %% [markdown]
# # SAGE
# Number of galaxies in sample at z=0: 750,000
#
# Number of galaxies in sample at z=1: 785,000
#
# Number of galaxies in sample at z=2: 580,000
#
# Number of galaxies in sample at z=3: 326,000
# # Dark SAGE
# Number of galaxies in sample at z=0: 700,000
#
# Number of galaxies in sample at z=1: 741,000
#
# Number of galaxies in sample at z=2: 500,000
#
# Number of galaxies in sample at z=3: 300,000

# %%
plt.figure(figsize=(10, 8))
binwidth = 0.1
NBINS = np.arange(min(spin_cen_z0Sage), max(spin_cen_z0Sage) + binwidth, binwidth)
fig = plt.figure(facecolor='white')

plt.subplot(221)
no_halos_hist = plt.hist(spin_cen_z0Sage, NBINS, normed=True, histtype = 'step', color='b', label='SAGE z=0')
#plt.plot(xx_kde, yy_kde, linestyle='-', color='r')
#plt.axvline(np.mean(spin_cen), color='orange', linestyle='--', linewidth=3, label='Mean')
#plt.axvline(np.median(spin_cen), color='orange', linestyle='-', linewidth=3,label='Median')
no_halos_hist = plt.hist(spin_cen_z1Sage, NBINS, normed=True, histtype = 'step', color='g', label='SAGE z=1')
no_halos_hist = plt.hist(spin_cen_z2Sage, NBINS, normed=True, histtype = 'step', color='r', label='SAGE z=2')
no_halos_hist = plt.hist(spin_cen_z3Sage, NBINS, normed=True, histtype = 'step', color='k', label='SAGE z=3')


plt.xlim(0, 5)
# plt.ylim(0, 11000)
plt.xlabel('Halo Spin Mpc*Km/s')
plt.ylabel('NBINS')
plt.title('Centrals Halo Spin Histogram')
# blue_patch = mpatches.Patch(color='blue', label='SAGE z=0')
# plt.legend(handles=[blue_patch], loc=1)
plt.legend(loc=1)


plt.subplot(222)
no_halos_hist = plt.hist(haloJ_cen_z0DSage, NBINS, normed=True, histtype = 'step', color='b', label='DSAGE z=0')
#plt.plot(xx_kde, yy_kde, linestyle='-', color='r')
#plt.axvline(np.mean(spin_cen), color='orange', linestyle='--', linewidth=3, label='Mean')
#plt.axvline(np.median(spin_cen), color='orange', linestyle='-', linewidth=3,label='Median')
no_halos_hist = plt.hist(haloJ_cen_z1DSage, NBINS, normed=True, histtype = 'step', color='g', label='DSAGE z=1')
no_halos_hist = plt.hist(haloJ_cen_z2DSage, NBINS, normed=True, histtype = 'step', color='r', label='DSAGE z=2')
no_halos_hist = plt.hist(haloJ_cen_z3DSage, NBINS, normed=True, histtype = 'step', color='k', label='DSAGE z=3')

plt.xlim(0, 5)
# plt.ylim(0, 11000)
plt.xlabel('Halo Spin Mpc*Km/s')
plt.ylabel('NBINS')
plt.title('Centrals Halo Spin Histogram')
# blue_patch = mpatches.Patch(color='blue', label='SAGE z=0')
# plt.legend(handles=[blue_patch], loc=1)
plt.legend(loc=1)
plt.style.use('seaborn-notebook')
plt.subplots_adjust(top=0.92, bottom=0.001, left=0.10, right=0.95, hspace=0.6,
                    wspace=0.35)
plt.savefig('Centrals_HaloSpin_histo_SAGE_DARKSAGE_z0toz3.png')
plt.show()

# %%
############# SAGE ###############
morph_cen_z0Sage = Bulge_cen_z0Sage/TSM_cen_z0Sage
morph_cen_z1Sage = Bulge_cen_z1Sage/TSM_cen_z1Sage
morph_cen_z2Sage = Bulge_cen_z2Sage/TSM_cen_z2Sage
morph_cen_z3Sage = Bulge_cen_z3Sage/TSM_cen_z3Sage

###### Redshift 0
bulgedom_idx_cen_z0Sage = np.where(morph_cen_z0Sage > 0.5)[0]
bulgedom_cen_z0Sage = gal_cen_z0Sage[bulgedom_idx_cen_z0Sage]

diskdom_idx_cen_z0Sage = np.where(morph_cen_z0Sage < 0.5)[0]
diskdom_cen_z0Sage = gal_cen_z0Sage[diskdom_idx_cen_z0Sage]

###### Redshift 1
bulgedom_idx_cen_z1Sage = np.where(morph_cen_z1Sage > 0.5)[0]
bulgedom_cen_z1Sage = gal_cen_z1Sage[bulgedom_idx_cen_z1Sage]

diskdom_idx_cen_z1Sage = np.where(morph_cen_z1Sage < 0.5)[0]
diskdom_cen_z1Sage = gal_cen_z1Sage[diskdom_idx_cen_z1Sage]

###### Redshift 2
bulgedom_idx_cen_z2Sage = np.where(morph_cen_z2Sage > 0.5)[0]
bulgedom_cen_z2Sage = gal_cen_z2Sage[bulgedom_idx_cen_z2Sage]

diskdom_idx_cen_z2Sage = np.where(morph_cen_z2Sage < 0.5)[0]
diskdom_cen_z2Sage = gal_cen_z2Sage[diskdom_idx_cen_z2Sage]

###### Redshift 3
bulgedom_idx_cen_z3Sage = np.where(morph_cen_z3Sage > 0.5)[0]
bulgedom_cen_z3Sage = gal_cen_z3Sage[bulgedom_idx_cen_z3Sage]

diskdom_idx_cen_z3Sage = np.where(morph_cen_z3Sage < 0.5)[0]
diskdom_cen_z3Sage = gal_cen_z3Sage[diskdom_idx_cen_z3Sage]

# %%
bulgedom_cen_z0Sage
# Out:
# FITS_rec([ (4.6242099999999997, 4.6242099999999997, 0.0104548, 0.0, 212.18700000000001, 0.0, 9.7012800000000006, 0.046151600000000001, 0.046151600000000001, 0.0, 0.32193300000000002, 0.0, 0.10267800000000001, 0, 0.0071657600000000002, 0.0, 0.0, 0.0, 0.0, 4003.5799999999999, 4003.5799999999999, 0.0, 1509.5899999999999, 0.40191399999999999, 401.91399999999999, 377.97000000000003, 250.82599999999999, -3.2084199999999998, 2.2046399999999999, -4.2743500000000001, 15247, 1509.5899999999999, 0.0, 0.0, 0.0, 425.37400000000002, 0, 7.5492138862609899, 5.5688948631286603, 27.286079406738299, -22.5364, -444.005, -262.84100000000001, 63, 64000000000, 64000000000, 19275003),
# ...

# %%
'''
############# DARK SAGE ###############
morph_cen_z0DSage = Bulge_cen_z0Sage/TSM_cen_z0Sage
morph_cen_z1DSage = Bulge_cen_z1Sage/TSM_cen_z1Sage
morph_cen_z2DSage = Bulge_cen_z2Sage/TSM_cen_z2Sage
morph_cen_z3DSage = Bulge_cen_z3Sage/TSM_cen_z3Sage

bulgedominating_cen_z0DSage = np.where(morph_cen_z0DSage < 0.5)[0]
diskdominating_cen_z0DSage = np.where(morph_cen_z0DSage > 0.5)[0]

bulgedominating_cen_z1DSage = np.where(morph_cen_z1DSage < 0.5)[0]
diskdominating_cen_z1DSage = np.where(morph_cen_z1DSage > 0.5)[0]

bulgedominating_cen_z2DSage = np.where(morph_cen_z2DSage < 0.5)[0]
diskdominating_cen_z2DSage = np.where(morph_cen_z2DSage > 0.5)[0]

bulgedominating_cen_z3DSage = np.where(morph_cen_z3DSage < 0.5)[0]
diskdominating_cen_z3DSage = np.where(morph_cen_z3DSage > 0.5)[0]
'''
# Out:
# '\n############# DARK SAGE ###############\nmorph_cen_z0DSage = Bulge_cen_z0Sage/TSM_cen_z0Sage\nmorph_cen_z1DSage = Bulge_cen_z1Sage/TSM_cen_z1Sage\nmorph_cen_z2DSage = Bulge_cen_z2Sage/TSM_cen_z2Sage\nmorph_cen_z3DSage = Bulge_cen_z3Sage/TSM_cen_z3Sage\n\nbulgedominating_cen_z0DSage = np.where(morph_cen_z0DSage < 0.5)[0]\ndiskdominating_cen_z0DSage = np.where(morph_cen_z0DSage > 0.5)[0]\n\nbulgedominating_cen_z1DSage = np.where(morph_cen_z1DSage < 0.5)[0]\ndiskdominating_cen_z1DSage = np.where(morph_cen_z1DSage > 0.5)[0]\n\nbulgedominating_cen_z2DSage = np.where(morph_cen_z2DSage < 0.5)[0]\ndiskdominating_cen_z2DSage = np.where(morph_cen_z2DSage > 0.5)[0]\n\nbulgedominating_cen_z3DSage = np.where(morph_cen_z3DSage < 0.5)[0]\ndiskdominating_cen_z3DSage = np.where(morph_cen_z3DSage > 0.5)[0]\n'

# %%
#

# %%
NBINS = 50
fig = plt.figure(facecolor='white')
no_halos_hist = plt.hist(morph_cen_z0Sage, NBINS, normed=True, histtype = 'step', color='b', label='SAGE z=0')
#no_halos_hist = plt.hist(morph_cen_z1Sage, NBINS, normed=True, histtype = 'step', color='g', label='SAGE z=1')
#no_halos_hist = plt.hist(morph_cen_z2Sage, NBINS, normed=True, histtype = 'step', color='r', label='SAGE z=2')
#no_halos_hist = plt.hist(morph_cen_z3Sage, NBINS, normed=True, histtype = 'step', color='k', label='SAGE z=3')
#plt.xlim(0, 2e9)
#plt.ylim(0, 5e-9)
plt.xlabel('Bulge Mass/Total Stellar Mass')
plt.ylabel('NBINS')
plt.title('Morphology Histogram')
plt.legend(loc=1)
plt.style.use('seaborn-notebook')
plt.show()
